# %%
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
# %matplotlib inline
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 20, 6

from statsmodels.graphics.tsaplots import plot_acf,plot_pacf
from statsmodels.tsa.statespace.tools import diff

# %%
df = pd.read_csv('android_high.csv')

# %%
df1 = pd.read_csv('android_low.csv')

# %%
df2 = pd.read_csv('h.264+mp3_TS.csv')

# %%
df3 = pd.read_csv('h.265+mp3.csv')

# %%
df4 = pd.read_csv('mpeg2+mpga.csv')

# %%
df = pd.read_csv('gns3.csv')
#android low with no transcoding

# %%
df1 = pd.read_csv('gns3_2.csv')
#android low with transcoding

# %%
b = pd.read_csv('buffered.csv')
#csv realized from R1,2,3 buffer public buffer increase

# %%
df.shape
# Out:
# (1557, 2)

# %%
df['Jitter'][:200].plot(marker='8')

# %%
df1.shape
# Out:
# (1417, 2)

# %%
df1['Jitter'].plot(marker='8')

# %%
b['Jitter'][:200].plot(marker='8')

# %%
x[:200].plot(marker='8')

# %%
df_march3 = pd.read_csv('3.3.csv')
#mpeg ts transcoding with reduced sample rate

# %%
df_march3['Jitter'].plot(marker='8')

# %%
df_andr_high = pd.read_csv('andr_high.csv')

# %%
df_andr_high['Jitter'][:].plot(marker='.')

# %%
#Read in csvfiles
#df1 = pd.read_csv('data/df_final.csv')
#df2 = pd.read_csv('data/df_final2.csv')

# %%
#Read in csvfiles
#df3 = pd.read_csv('capture feb 11/df.csv')  ## gns3 3-state
#df4 = pd.read_csv('data_feb12/x12.csv')
df = pd.read_csv('18.02.gns3.csv')

# %%
df['Time'] = np.arange(1,len(df)+1)

# %%
df = df.set_index('Time')
df.index.freq = 'ms'

# %%
from statsmodels.tsa.statespace.tools import diff

# %%
df.head()
# Out:
#         Jitter
# Time
# 1     0.000000
# 2     0.616403
# 3     1.209155
# 4     1.748548
# 5     2.270924

# %%
df['Jitter'][2000:3000].plot(marker='o');

# %%
df['diff1'] = df['Jitter'].diff()

# %%
df['diff2'] = df['diff1'].diff()

# %%
df['diff1'].plot();

# %%
df['diff2'][:500].plot();

# %%
dxxx.head(20)
# Out:
#         Jitter      EWMA        d2        d3
# Time
# 1     2.720997  2.720997       NaN       NaN
# 2     2.593453  2.716815       NaN       NaN
# 3     2.472111  2.708792 -0.248886       NaN
# 4     2.360416  2.697370 -0.233037       NaN
# 5     2.254214  2.682840 -0.217897       NaN
# 6     2.155150  2.665539 -0.205266       NaN
# 7     2.064121  2.645820 -0.190093       NaN
# 8     1.977326  2.623903 -0.177825       NaN
# 9     1.894992  2.600004 -0.169129       NaN
# 10    1.820373  2.574442 -0.156953       NaN
# 11    1.748468  2.547361 -0.146524 -0.972529
# 12    1.681750  2.518980 -0.138623 -0.911702
# 13    1.619890  2.489502 -0.128578 -0.852221
# 14    3.371579  2.518423  1.689829  1.011163
# 15    3.194380  2.540585  1.574489  0.940165
# 16    3.018519  2.556255 -0.353060  0.863369
# 17    2.854044  2.566019 -0.340335  0.789923
# 18    2.698281  2.570355 -0.320239  0.720955
# 19    2.553589  2.569805 -0.300456  0.658597
# 20    2.419122  2.564865 -0.279158  0.598749

# %%
dxxx['d3'].plot(marker='*');

# %%
dxxx['d2_n0>NA'] = dxxx['d2'].dropna()

# %%
dxxx['d2_n0>NA'][750:800].plot(marker='*')

# %%
dxxx['Jitter'][750:900].plot(marker='*')

# %%
df.tail()
# Out:
#           Jitter    Time
# 253005  2.265083  253006
# 253006  2.216443  253007
# 253007  2.172518  253008
# 253008  2.126236  253009
# 253009  2.088299  253010

# %%
df.shape
# Out:
# (253010, 2)

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df = df.set_index('Time')
df.index.freq = 'ms'

# %%
df.index.freq = 'ms'

# %%
from statsmodels.tsa.statespace.tools import diff

# %%
df.head()
# Out:
#         Jitter
# Time
# 1     2.720997
# 2     2.593453
# 3     2.472111
# 4     2.360416
# 5     2.254214

# %%
d_transformed = df.copy()

# %%
#x['d2'] = diff(x['Jitter'])                      statsmodel
#df2['d1'] = df2['b'] - df2['b'].shift(1)         pandas

# %%
d_transformed.head()
# Out:
#         Jitter
# Time
# 1     2.720997
# 2     2.593453
# 3     2.472111
# 4     2.360416
# 5     2.254214

# %%
d_transformed['diff2'] = d_transformed['Jitter'].diff().diff()

# %%
dxxx = df.copy()

# %%
dxxx.head()
# Out:
#         Jitter      EWMA
# Time
# 1     2.720997  2.720997
# 2     2.593453  2.716815
# 3     2.472111  2.708792
# 4     2.360416  2.697370
# 5     2.254214  2.682840

# %%
dxxx['d2'] = dxxx['Jitter'] - dxxx['Jitter'].shift(2)

# %%
dxxx.head()
# Out:
#         Jitter      EWMA        d2
# Time
# 1     2.720997  2.720997       NaN
# 2     2.593453  2.716815       NaN
# 3     2.472111  2.708792 -0.248886
# 4     2.360416  2.697370 -0.233037
# 5     2.254214  2.682840 -0.217897

# %%
d_transformed.head()
# Out:
#         Jitter     diff1     diff2
# Time
# 3     2.472111 -0.121341  0.006203
# 4     2.360416 -0.111695  0.009646
# 5     2.254214 -0.106202  0.005493
# 6     2.155150 -0.099064  0.007138
# 7     2.064121 -0.091029  0.008035

# %%
d_transformed.dropna(inplace=True);

# %%
d_transformed['diff1'].plot()

# %%
dxxx['d2'].plot()

# %%
d_transformed['diff2'].plot()

# %% [markdown]
# ## Tests on Stationarity

# %%
from statsmodels.tsa.stattools import adfuller
def adf_test(series,title=''):
    """
    Pass in a time series and an optional title, returns an ADF report
    """
    print(f'Augmented Dickey-Fuller Test: {title}')
    result = adfuller(series.dropna(),autolag='AIC') # .dropna() handles differenced data
    
    labels = ['ADF test statistic','p-value','# lags used','# observations']
    out = pd.Series(result[0:4],index=labels)

    for key,val in result[4].items():
        out[f'critical value ({key})']=val
        
    print(out.to_string())          # .to_string() removes the line "dtype: float64"
    
    if result[1] <= 0.05:
        print("Strong evidence against the null hypothesis")
        print("Reject the null hypothesis")
        print("Data has no unit root and is stationary")
    else:
        print("Weak evidence against the null hypothesis")
        print("Fail to reject the null hypothesis")
        print("Data has a unit root and is non-stationary")

# %%
adf_test(df4_transformed['Jitter'])
#adf_test(df['Money'],title='Money')
# Out:
# Augmented Dickey-Fuller Test:
# ADF test statistic         -69.758520
# p-value                      0.000000
# # lags used                 86.000000
# # observations          252922.000000
# critical value (1%)         -3.430376
# critical value (5%)         -2.861551
# critical value (10%)        -2.566776
# Strong evidence against the null hypothesis
# Reject the null hypothesis
# Data has no unit root and is stationary

# %% [markdown]
# ## Run EWMA on all dataset

# %%
#EWMA on df - original dataset (no differncing)

# %%
df['EWMA'] = df['Jitter'].ewm(span=60,adjust=False).mean()

# %%
df.plot();

# %%
d_transformed.head()
# Out:
#         Jitter     diff1     diff2
# Time
# 3     2.472111 -0.121341  0.006203
# 4     2.360416 -0.111695  0.009646
# 5     2.254214 -0.106202  0.005493
# 6     2.155150 -0.099064  0.007138
# 7     2.064121 -0.091029  0.008035

# %%
#EWMA on d_transformed - differenced dataset

# %%
d_transformed['diff1_EWMA'] = d_transformed['diff1'].ewm(span=60,adjust=False).mean()

# %%
d_transformed['diff2_EWMA'] = d_transformed['diff2'].ewm(span=60,adjust=False).mean()

# %%
d_transformed.columns
# Out:
# Index(['Jitter', 'diff1', 'diff2', 'diff1_EWMA', 'diff2_EWMA'], dtype='object')

# %%
d_transformed[['diff1', 'diff1_EWMA']].plot();

# %%
d_transformed[['diff2', 'diff2_EWMA']].plot();

# %% [markdown]
# ## When forecasting with first/second order differences, the predicted values have to be added back in to the original values in order to obtain an appropriate forecast.

# %%
d_transformed['diff1_pred'] = d_transformed['Jitter'].iloc[-1] + d_transformed['diff1_EWMA'].cumsum()

# %%
d_transformed[['Jitter','diff1_pred']].plot();

# %%
# Add the most recent first difference from the training set to the Fcast cumulative sum
d_transformed['firstdiff'] = (d_transformed['Jitter'].iloc[-1]-d_transformed['Jitter'].iloc[-2]) + d_transformed['diff1_EWMA'].cumsum()

# Now build the forecast values from the first difference set
d_transformed['diff2_pred'] = d_transformed['Jitter'].iloc[-1] + d_transformed['firstdiff'].cumsum()

# %%
# Get the second order diff reversed
'''

forecast = []

# Capture the two most recent values from the training set
v2,v1 = df2['c'].iloc[-2:]

# Apply the formula
for i in z['Fcast']:
    newval = i + 2*v1 - v2
    forecast.append(newval)
    v2,v1 = v1,newval

z['forecast']=forecast
z

'''
# Out:
# "\n\nforecast = []\n\n# Capture the two most recent values from the training set\nv2,v1 = df2['c'].iloc[-2:]\n\n# Apply the formula\nfor i in z['Fcast']:\n    newval = i + 2*v1 - v2\n    forecast.append(newval)\n    v2,v1 = v1,newval\n\nz['forecast']=forecast\nz\n\n"

# %% [markdown]
# ## Smoothed Exponential on Individual States

# %%
#df = df4[['Jitter']]  ### Preserve the df4 dataframe

#   del df_low['ewma_low']  -- sure works and preserves the type as DF or df.drop('col_name', axis=1, inplace=True (dont reassign))

# %%
df.head()
# Out:
#         Jitter      EWMA
# Time
# 1     2.720997  2.720997
# 2     2.593453  2.716815
# 3     2.472111  2.708792
# 4     2.360416  2.697370
# 5     2.254214  2.682840

# %% [markdown]
# ## Train on low jitter df and predict on intermediate jitter and high jitter df

# %%
#Low Jitter area - Generate a DF with Low and Intermediate Jitter 
df_low = df[['Jitter']][:52000]

# %%
df_low.tail()
# Out:
#          Jitter
# Time
# 51996  1.170189
# 51997  1.159852
# 51998  1.166011
# 51999  1.165986
# 52000  1.168211

# %%
df_low.plot()

# %%
df_low['ewma'] = df_low['Jitter'].ewm(span=60,adjust=False).mean()

# %%
df_low.plot();

# %%
train_len = int(26000)

# %%
train = df_low[0:train_len]
test = df_low[train_len:]

print('Train data length :', len(train))
print('Test data length :', len(test))
# Out:
# Train data length : 26000
# Test data length : 26000

# %%
#train=df_low[0:train_len]
#test=df_low[train_len:]

# %%
y_hat_avg = test.copy()

# %%
plt.plot(train['Jitter'], Label='Low Jitter')
plt.plot(test['Jitter'],Label='Intermediate Jitter')
plt.plot(y_hat_avg['ewma'], Label='EWMA')
plt.legend(loc='best')
plt.show();

# %%
df_low['ewma'].plot()

# %%
df_low['ewma'][25800:27000].plot()

# %%
x_avg = train.copy() #average ewma in train

# %%
err_tr = x_avg['Jitter'] - x_avg['ewma']

# %%
err_tr.shape
# Out:
# (26000,)

# %%
epochs = range(len(err_tr))

# %%
plt.plot(epochs,err_tr) #smaller variance noticed from the plots

# %%
#sns.kdeplot(data=err_tr,bw=1.5)

# %%
err_tr.describe()
# Out:
# count    26000.000000
# mean         0.002883
# std          0.466817
# min         -4.050552
# 25%         -0.152197
# 50%         -0.037847
# 75%          0.109563
# max          9.073798
# dtype: float64

# %%
err_test = y_hat_avg['Jitter'] - y_hat_avg['ewma']

# %%
err_test.plot();

# %%
err_test.describe()
# Out:
# count    26000.000000
# mean        -0.001843
# std          1.624272
# min         -8.321563
# 25%         -0.665458
# 50%         -0.143098
# 75%          0.427551
# max         29.562447
# dtype: float64

# %%
err.values
# Out:
# array([ 0.        , -0.12336248, -0.23668089, ..., -2.6411705 ,
#        -2.5545996 , -2.46868931])

# %%
sns.kdeplot(data=err_tr)
sns.kdeplot(data=err_test)

# %%
x_avg.mean()
# Out:
# Jitter    0.909073
# ewma      0.906191
# dtype: float64

# %%
#x_avg['ewma'].plot()
#y_hat_avg['ewma'].plot()
y_hat_avg.mean()
# Out:
# Jitter    2.960639
# ewma      2.962482
# dtype: float64

# %%
err = df_low['Jitter'] - df_low['ewma']

# %%
err.plot()

# %%
train['Jitter'].mean()
# Out:
# 0.9090731741012079

# %%
x_avg['ewma'].mean()
# Out:
# 0.9061905326668176

# %%
sns.kdeplot(err,bw=0.8)

# %%
y_hat_avg.describe()
# Out:
#              Jitter          ewma
# count  26000.000000  26000.000000
# mean       2.960639      2.962482
# std        2.925956      2.416404
# min        0.000000      0.108288
# 25%        0.972417      1.249182
# 50%        1.861676      2.205024
# 75%        3.950789      3.882295
# max       33.888837     15.957577

# %%
train.describe()
# Out:
#              Jitter          ewma
# count  26000.000000  26000.000000
# mean       0.909073      0.906191
# std        0.955423      0.818377
# min        0.019477      0.042291
# 25%        0.379192      0.441104
# 50%        0.624572      0.655007
# 75%        1.094512      1.109015
# max       11.834733      8.971265

# %% [markdown]
# ## Include the high jitter value range

# %%
# Include the high jitter value range
#Low Jitter area - Generate a DF with Low and Intermediate Jitter 
df_x = df[['Jitter']][:80000]

# %%
#create train and test sets
train_dfx = df_x[0:train_len]
test_dfx = df_x[train_len:]

print('Train data length :', len(train_dfx))
print('Test data length :', len(test_dfx))
# Out:
# Train data length : 26000
# Test data length : 54000

# %%
y_hat_dfx = test_dfx.copy()

# %%
df_x['ewma'] = df_x['Jitter'].ewm(span=60,adjust=False).mean()

# %%
plt.plot(train_dfx['Jitter'], Label='Low Jitter')
plt.plot(test_dfx['Jitter'],Label='Intermediate Jitter')
plt.plot(y_hat_dfx['ewma'], Label='EWMA')
plt.legend(loc='best')
plt.show();

# %%
#df_x[25999:27000]

# %%
test_dfx.mean()
# Out:
# Jitter    4.019107
# ewma      4.021490
# dtype: float64

# %%
train_dfx.mean()
# Out:
# Jitter    0.909073
# ewma      0.906191
# dtype: float64

# %%
from sklearn.metrics import mean_squared_error
rmse = np.sqrt(mean_squared_error(test_dfx.Jitter, y_hat_dfx.ewma))
rmse = round(rmse, 3)
print(rmse)
# Out:
# 2.16

# %% [markdown]
# ## Train on HJ and predict on intermediate and low jitter

# %%
df['Jitter'][123000:200000].plot()

# %%
# Include the high jitter value range
#Low Jitter area - Generate a DF with Low and Intermediate Jitter 
df_high = df[['Jitter']][123000:200000]

# %%
df_high['ewma'] = df_high['Jitter'].ewm(span=60,adjust=False).mean()

# %%
df_high['sma'] = df_high['Jitter'].rolling(30).mean()

# %%
df_high.head()
# Out:
#           Jitter      ewma  sma
# Time
# 123001  1.631657  1.631657  NaN
# 123002  1.615358  1.631123  NaN
# 123003  1.584919  1.629608  NaN
# 123004  1.552313  1.627073  NaN
# 123005  1.527481  1.623808  NaN

# %%
#create train and test sets
train_df_high = df_high[0:train_len]
test_df_high = df_high[train_len:]

print('Train data length :', len(train_df_high))
print('Test data length :', len(test_df_high))
# Out:
# Train data length : 26000
# Test data length : 51000

# %%
y_hat_df_high = test_df_high.copy()

# %%
plt.plot(train_df_high['Jitter'], Label='Low Jitter')
plt.plot(test_df_high['Jitter'],Label='Intermediate Jitter')
plt.plot(y_hat_df_high['ewma'], Label='EWMA')
plt.legend(loc='best')
plt.show();

# %%
plt.plot(train_df_high['Jitter'], Label='Low Jitter')
plt.plot(test_df_high['Jitter'][:4000],Label='Intermediate Jitter')
plt.plot(y_hat_df_high['sma'][:4000], Label='SMA')
plt.legend(loc='best')
plt.show();

# %%
err_df_high_train = train_df_high['Jitter'] - train_df_high['ewma']

# %%
err_df_high_test = test_df_high['Jitter'] - test_df_high['ewma']

# %%
#y_hat_df_high.Jitter.mean()

# %%
test_df_high.describe()
# Out:
#              Jitter          ewma
# count  51000.000000  51000.000000
# mean       2.138664      2.137439
# std        2.493879      2.271395
# min        0.014134      0.024620
# 25%        0.486244      0.585199
# 50%        1.165386      1.257860
# 75%        2.730158      2.711087
# max       29.215947     14.793895

# %%
y_hat_df_high.describe()
# Out:
#              Jitter          ewma
# count  51000.000000  51000.000000
# mean       2.138664      2.137439
# std        2.493879      2.271395
# min        0.014134      0.024620
# 25%        0.486244      0.585199
# 50%        1.165386      1.257860
# 75%        2.730158      2.711087
# max       29.215947     14.793895

# %%
train_df_high.ewma.mean()
# Out:
# 7.862768955234805

# %%
test_df_high.ewma.mean()
# Out:
# 2.1374394804276244

# %%
d_transformed.head()
# Out:
#         Jitter     diff1     diff2  diff1_EWMA  diff2_EWMA  diff1_pred  \
# Time
# 3     2.472111 -0.121341  0.006203   -0.121341    0.006203    1.966957
# 4     2.360416 -0.111695  0.009646   -0.121025    0.006316    1.845932
# 5     2.254214 -0.106202  0.005493   -0.120539    0.006289    1.725393
# 6     2.155150 -0.099064  0.007138   -0.119835    0.006317    1.605558
# 7     2.064121 -0.091029  0.008035   -0.118891    0.006373    1.486667
#
#       firstdiff  diff2_pred
# Time
# 3     -0.159278    1.929020
# 4     -0.280304    1.648717
# 5     -0.400843    1.247874
# 6     -0.520678    0.727196
# 7     -0.639569    0.087627

# %% [markdown]
# ## Differenced dataset

# %%
#Low Jitter area - Generate a DF with Low and Intermediate Jitter 
#d_t = df[['Jitter']][:52000]

d = d_transformed.copy()

# %%
d = d_transformed[['Jitter', 'diff1']][:52000]

# %%
d['ewma'] = d['diff1'].ewm(span=60,adjust=False).mean()

# %%
train_d = d[0:train_len]
test_d = d[train_len:]

# %%
y_hat_d = test_d.copy()

# %%
plt.plot(train_d['diff1'], Label='Low Jitter')
plt.plot(test_d['diff1'],Label='Intermediate Jitter')
plt.plot(y_hat_d['ewma'], Label='EWMA')
plt.legend(loc='best')
plt.show();

# %% [markdown]
# ## error on diff subset

# %%
d.head()
# Out:
#         Jitter     diff1      ewma
# Time
# 3     2.472111 -0.121341 -0.121341
# 4     2.360416 -0.111695 -0.121025
# 5     2.254214 -0.106202 -0.120539
# 6     2.155150 -0.099064 -0.119835
# 7     2.064121 -0.091029 -0.118891

# %%
err_diff_subset = d['diff1'] - d['ewma']

# %%
err_diff_subset.plot()

# %%
d.head()
# Out:
#         Jitter     diff1      ewma
# Time
# 3     2.472111 -0.121341 -0.121341
# 4     2.360416 -0.111695 -0.121025
# 5     2.254214 -0.106202 -0.120539
# 6     2.155150 -0.099064 -0.119835
# 7     2.064121 -0.091029 -0.118891

# %%
d.columns
# Out:
# Index(['Jitter', 'diff1', 'ewma'], dtype='object')

# %%
d[['diff1', 'ewma']].plot()

# %%
d_transformed['diff1_pred'].plot()

# %%
d_transformed['diff1_pred'].describe()
# Out:
# count    253008.000000
# mean         -0.684917
# std           3.605373
# min          -4.060108
# 25%          -3.270093
# 50%          -2.117292
# 75%           0.760301
# max          22.187596
# Name: diff1_pred, dtype: float64

# %%
#sns.lineplot(data=err[26000:26020])

#spikes around the state swap regions - error curve

# %% [markdown]
# ## Error plots

# %%
err_diff = d_transformed['diff1'] - d_transformed['diff1_EWMA']

# %%
err_diff.plot()

# %%
err_all_real = df['Jitter'] - df['EWMA']
err_all_real.plot();

# %%
err_df_high_train.plot();

# %%
err_df_high_test.plot();

# %%
err_df_high_train.describe()
# Out:
# count    26000.000000
# mean         0.001658
# std          2.950795
# min        -10.699640
# 25%         -1.637266
# 50%         -0.217764
# 75%          1.503844
# max         14.822964
# dtype: float64

# %%
err_df_high_test.describe()
# Out:
# count    51000.000000
# mean         0.001224
# std          1.010283
# min         -5.843990
# 25%         -0.318857
# 50%         -0.055727
# 75%          0.234175
# max         26.098127
# dtype: float64

# %%
#Error from df_high to check transition 
err_df_high = df_high['Jitter'] - df_high['ewma']

# %%
err_df_high.plot();

# %% [markdown]
# ## error on first 52000 traces in actual vs diff data

# %%
err.plot();

# %%
err_diff_subset.plot()

# %%
df4.head()
# Out:
#       Jitter
# 0  27.209970
# 1  25.934528
# 2  24.721113
# 3  23.604161
# 4  22.542144

# %%
d['ewma'][25800:27000].plot()

# %%
np.random.randint(0,8)
# Out:
# 7
