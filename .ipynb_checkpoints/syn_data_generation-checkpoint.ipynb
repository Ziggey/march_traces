# %%
from scipy.optimize import curve_fit
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 20, 6

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

data = np.random.exponential(5, size=1000)

hist,edges = np.histogram(data,bins="auto",density=True )

x = edges[:-1]+np.diff(edges)/2.
plt.scatter(x,hist)

func = lambda x,beta: 1./beta*np.exp(-x/beta)

popt, pcov = curve_fit(f=func, xdata=x, ydata=hist) 

print(popt)

xx = np.linspace(0, x.max(), 101)
plt.plot(xx, func(xx,*popt), ls="--", color="k", 
         label="fit, $beta = ${}".format(popt))
plt.legend()
plt.show()
# Out:
# [5.19258711]

# %%
hist,edges = np.histogram(data,bins="auto",density=True )

x = edges[:-1]+np.diff(edges)/2.
plt.scatter(x,hist)

# %% [markdown]
# ## Data Generation

# %%
x = np.linspace(-1,2, 40)
y = np.exp(-x)

plt.plot(x,y,'o')

# %%
plt.plot(x,y,'o')

# %%
plt.plot(x, np.exp(-x),'o')

# %%
y_ = y.tolist()

# %%
y_.extend(y_)

# %%
len(y_)
# Out:
# 160

# %%
x_ = np.linspace(1,100,160)

# %%
plt.plot(x_,y_,'o')

# %%
y = np.exp(-x_)

# %%
from scipy import signal

M =  51 
tau = 3.0

tau2 = -(M-1) / np.log(0.01)
window2 = signal.exponential(M, 0, tau2, False)
plt.figure()
plt.plot(window2, 'o')
plt.ylabel("Amplitude")
plt.xlabel("Sample")
# Out:
# Text(0.5, 0, 'Sample')

# %%
w = signal.exponential(M, 0, tau2, False)

# %%
xw = np.arange(0, len(w))
plt.plot(xw,w)

# %% [markdown]
# ## Data Generation using Scipy.Signal.Exponential

# %%
z = np.arange(50,200,10)
#z = np.arange(10,300,10)
w = []

for i in z:
    M = i
    
    tau2 = -(M-1) / np.log(0.01)
    
    window = signal.exponential(M, 0, tau2, False)
    window.tolist()
    w.append(window)
   
   
    #print('M :', i)

# %%
flattened_list = []
for x in w:
    for y in x:
        flattened_list.append(y)
        
        
#flatten the lists
#flattened_list = [y for x in list_of_lists for y in x]

# %%
len(flattened_list)
# Out:
# 1800

# %%
x = np.arange(0, len(flattened_list))
y = flattened_list

plt.plot(x,y,'o')

# %%
#x1 = np.linspace(-2,1, 40)
#y1 = np.exp(-x1)

#plt.plot(x1,y1,'ro')

# %%
plt.plot(np.arange(0,len(y)),y,'o')

# %%
sample = [(-5,5),(-4,4),(-3,3),(-2,2),(-1,1),(-1,2),(-1,3),(-1,4),(-1,5),
          (-2,1),(-2,2),(-2,3),(-2,4),(-2,5),
          (-3,1),(-3,2),(-3,3),(-3,4),(-3,5),
          (-4,1),(-4,2),(-4,3),(-4,4),(-4,5),
          (-5,1),(-5,2),(-5,3),(-5,4)]
n = 50

y_new = []

for i in sample:
    x0 = np.linspace(i[0], i[1], n)
    y0 = np.exp(-x0)
    
    y_new.extend(y0)

# %%
len(y_new)
# Out:
# 1400

# %%
plt.plot(np.arange(0,len(y_new)),y_new,'o')
plt.ylim(0,140)
# Out:
# (0, 140)

# %%
#signal.exp returns normalized values, increase the values


multiplied_list = [element * 100 for element in y[:500]]
#multiplied_list

# %%
plt.plot(np.arange(0,len(y)),y,'o')

# %%
y_new.extend(multiplied_list)

# %%
plt.plot(np.arange(0,len(y_new)),y_new,'o')
#plt.xlim(0,500)

# %%
y_x = [element * 60 for element in y_new[150:350]]

# %%
len(y_new)
# Out:
# 2150

# %%
len(y_x)
# Out:
# 200

# %%
test_list = [1,2,3,4,5]

# %%
insert_list = [1500, 2000, 3000]

# %%
test_list[2]
# Out:
# 150

# %%
pos = 2
test_list[pos:pos] = insert_list

# %%
test_list
# Out:
# [1, 2, 1500, 2000, 3000, 150, 200, 300, 3, 4, 5]

# %%
pop_ind = 149

y_new[pop_ind:pop_ind] = y_x

# %%
plt.plot(np.arange(0,len(y_new)),y_new,'o')

# %%
tl = np.array(test_list)
tl
# Out:
# array([   1,    2, 1500, 2000, 3000,  150,  200,  300,    3,    4,    5])

# %%
tl[:2]*5.0
# Out:
# array([ 5., 10.])

# %%
tl
# Out:
# array([   1,    2, 1500, 2000, 3000,  150,  200,  300,    3,    4,    5])
