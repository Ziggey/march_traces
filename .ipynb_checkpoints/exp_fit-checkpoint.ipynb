# %%
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
# %matplotlib inline
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 18, 6
from scipy.optimize import curve_fit

# %%
def exp_decay(x,a,r):
    return a * ((1-r)**x)

# %%
x = np.linspace(0,50,50)

# %%
y = exp_decay(x, 400, 0.06)

# %%
y1 = exp_decay(x, 550, 0.06)

# %%
plt.plot(x, y, 'o')

# %%
plt.scatter(x,y1)

# %%
pars, cov = curve_fit(exp_decay, x, y, p0=[0,0])

# %%
plt.scatter(x,y)
plt.plot(x, exp_decay(x, *pars), 'r-')

# %%
pars
# Out:
# array([4.e+02, 6.e-02])

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y, exp_decay(x, *pars))
# Out:
# 1.0

# %%
y
# Out:
# array([400.        , 375.52550064, 352.54850407, 330.97738373,
#        310.72611931, 291.71395379, 273.86507134, 257.10829506,
#        241.37680305, 226.60786202, 212.74257708, 199.72565691,
#        187.50519326, 176.03245392, 165.26168847, 155.14994575,
#        145.65690263, 136.7447032 , 128.37780782, 120.52285138,
#        113.14851026, 106.2253774 ,  99.72584507,  93.62399475,
#         87.89549375,  82.51749823,  77.46856209,  72.7285514 ,
#         68.27856419,  64.100855  ,  60.17876416,  56.49665135,
#         53.03983321,  49.7945248 ,  46.74778463,  43.88746307,
#         41.20215385,  38.68114863,  36.31439426,  34.09245272,
#         32.00646343,  30.04810801,  28.20957701,  26.48353882,
#         24.86311044,  23.34182999,  21.91363098,  20.57281811,
#         19.31404455,  18.13229062])

# %%
yx = np.append(y,y1)

# %%
y.size
# Out:
# 50

# %%
y1.size
# Out:
# 50
