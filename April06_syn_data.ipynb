# %%
from scipy.optimize import curve_fit
import random
from scipy import signal
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 20, 6

# %%
df = pd.read_csv('h.264+mp3_TS.csv')

# %%
df['Jitter'].plot(marker='8')
#plot the data

# %%
from statsmodels import api as sm
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf
from statsmodels.tsa.statespace.tools import diff

# %%
def autocrr_peak(x):
    
    n = np.arange(50,len(x),100)
    
    acfs = []
    peaks_pos = []
    
    for i in n:
        acf = sm.tsa.acf(x[:i], nlags=i)
        plt.figure(figsize = (10, 8))
        lag = np.arange(len(x[:i]))
                        
        peaks_positive, _ = signal.find_peaks(acf, threshold=None)
        #peaks_positive, _ = signal.find_peaks(acf, height=0.0, threshold=None)
                   
        plt.plot(lag, acf,'b-')
        plt.plot(lag[peaks_positive], acf[peaks_positive], 'ro')
        print (peaks_positive, 'for : ', i)
        plt.xlabel('No. of Lags: ' + str(i))
        plt.ylabel('Autocorrelation')

# %%
jitter = df.Jitter.values

# %%
autocrr_peak(jitter[:2000])
# Out:
# [] for :  50
# [ 23  46  62  85 108 113] for :  150
# [ 23  37  46  62  76  85 108 161 184 211 243] for :  250
# [ 46  78 108 154 161 184 239 262 322 341] for :  350
# [ 46  78 108 122 124 156 184 193 202 232 239 262 278 324 340 363 386] for :  450
# [ 39  46  78  85 108 124 156 161 163 184 193 202 241 262 278 317 340 363
#  386 402 425 464 480 503 513 546] for :  550
# [ 23  39  46  78  85 108 124 163 184 202 241 248 262 278 317 324 340 363
#  386 395 402 425 441 480 503 526 549 565 588] for :  650
# [ 39  78 108 124 163 184 202 241 245 262 278 317 319 324 340 363 365 386
#  395 402 425 441 480 485 503 526 549 562 565 588 631 647 670 686 709 714] for :  750
# [ 23  39  78  85 108 124 163 184 202 241 245 262 278 284 326 330 340 369
#  386 404 408 425 441 447 454 486 493 526 532 549 565 571 588 593 608 647
#  670 686 693 709 716 732 755 771 794] for :  850
# [ 39  78 124 163 184 202 245 262 278 280 283 326 330 340 369 386 407 425
#  446 487 492 526 532 549 570 588 608 648 670 686 716 724 732 755 770 794
#  803 809 832 911] for :  950
# [  39   78  124  163  184  202  245  262  278  280  283  330  340  369
#   386  407  425  441  446  454  487  492  526  532  549  570  588  608
#   610  625  647  671  686  693  716  724  732  755  770  794  809  832
#   903  949  964 1011] for :  1050
# [  23   39   78  124  163  184  202  242  244  262  280  326  330  369
#   386  407  425  446  487  492  526  532  549  570  588  593  610  648
#   670  688  709  716  724  732  755  771  794  809  832  852  890  928
#   966 1013 1036 1049 1051 1074 1111 1129] for :  1150
# [  23   39   78  124  163  184  202  242  244  262  280  324  326  330
#   340  365  369  386  407  425  443  446  487  526  532  549  570  588
#   603  608  610  648  670  688  709  727  732  766  770  794  805  809
#   812  832  851  890  928  968 1007 1012 1036 1044 1074 1083 1129 1152
#  1168 1191 1211 1248] for :  1250
# [  39   58   62   78  124  163  184  202  242  244  262  280  324  326
#   330  340  369  386  407  425  446  454  487  492  526  532  549  570
#   588  610  648  688  709  727  732  766  770  786  794  812  824  832
#   851  863  871  890  909  928  949  968  987 1007 1012 1027 1036 1044
#  1065 1074 1083 1103 1129 1141 1152 1168 1191 1211 1249 1311] for :  1350
# [  39   62   78  124  163  184  202  242  244  262  280  326  330  340
#   369  386  407  425  446  454  487  492  526  532  549  570  588  610
#   648  688  693  709  716  727  732  747  755  766  770  786  794  812
#   821  824  832  851  860  863  890  909  928  949  968  984  987 1013
#  1023 1027 1036 1044 1069 1074 1083 1103 1129 1147 1152 1168 1191 1211
#  1225 1249 1301 1305 1347 1386 1409] for :  1450
# [  39   58   62   78  124  163  184  202  242  244  262  280  330  369
#   386  408  425  446  454  487  492  526  532  549  570  588  610  649
#   688  693  716  727  732  755  766  771  786  794  812  821  824  852
#   860  890  899  906  929  938  945  968  974  984 1013 1023 1027 1036
#  1044 1051 1065 1069 1083 1090 1101 1147 1191 1211 1225 1249 1303 1347
#  1379 1386 1409 1425 1487] for :  1550
# [  39   62   78   85  124  163  184  202  242  244  262  280  283  330
#   369  386  408  425  446  454  487  492  526  532  543  549  570  588
#   610  649  688  693  716  727  732  747  755  766  771  774  778  785
#   794  812  824  852  856  860  863  890  899  906  909  929  938  945
#   948  968  974  984  986 1007 1027 1030 1036 1044 1051 1069 1103 1108
#  1115 1152 1193 1211 1225 1232 1239 1271 1278 1303 1310 1317 1347 1356
#  1386 1395 1409 1425 1432 1471 1487 1517 1540 1556 1579 1611 1643] for :  1650
# [  39   62   78   85  124  163  184  202  245  280  330  369  386  408
#   425  446  453  487  492  526  532  543  549  571  577  588  593  610
#   628  631  649  688  693  716  727  732  747  755  766  771  778  785
#   794  812  824  852  863  870  890  902  906  909  929  948  968  974
#   987  991 1007 1027 1030 1044 1069 1103 1108 1115 1129 1152 1154 1193
#  1211 1226 1232 1239 1271 1278 1303 1317 1347 1356 1363 1395 1425 1432
#  1473 1480 1487 1510 1517 1556 1579 1595 1602 1641 1657 1664 1730] for :  1750
# [  39   59   78   85  108  124  163  184  202  245  280  330  369  386
#   408  425  446  487  492  526  532  549  571  577  583  590  593  603
#   610  628  631  649  675  688  693  700  727  732  747  755  766  771
#   774  778  785  794  812  824  852  863  890  909  929  948  966  987
#   991 1007 1030 1033 1051 1069 1103 1108 1115 1129 1154 1193 1211 1226
#  1232 1239 1278 1317 1340 1356 1363 1395 1402 1425 1432 1441 1448 1473
#  1480 1487 1510 1517 1526 1556 1579 1595 1602 1634 1641 1657 1664 1680
#  1726 1742 1749 1788 1812 1841] for :  1850
# [  39   59   78   85  108  124  163  202  245  280  330  369  386  408
#   425  446  487  492  526  532  549  571  577  588  590  610  628  649
#   675  688  693  713  716  727  732  739  747  755  766  771  774  778
#   785  794  805  812  824  852  863  870  890  909  929  948  966  968
#   988 1002 1007 1027 1030 1033 1069 1074 1108 1111 1115 1129 1154 1193
#  1211 1232 1239 1271 1278 1317 1340 1356 1363 1395 1402 1409 1425 1434
#  1448 1480 1517 1526 1529 1558 1572 1579 1595 1602 1636 1641 1646 1650
#  1657 1664 1680 1726 1742 1749 1758 1820 1834 1869 1916] for :  1950

# %%
plt.plot(jitter[1704:1744], 'o')

# %%
arr = [10, 20, 80, 30, 60, 50, 
                     110, 100, 130, 170]

x = 110

for i in arr:   
    if i == x:
        print(arr.index(i))
# Out:
# 6

# %%
def lin_search(x,z):
    for i in x:
        if i == z:
            return arr.index(i)
    return print('Not found')

# %%
lin_search(arr, 1000)
# Out:
# Not found

# %%
for i in range(len(arr)):
    if arr[i] == 110:
        print(i)
# Out:
# 6
